# %%
import pandas as pd
a=[1, 7, 2]
myvar=pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
ca = {"day1":420, "day2:":380, "day3":390}
myvar=pd.Series(ca)
ca
# Out:
# {'day1': 420, 'day2:': 380, 'day3': 390}

# %%
ca = {"day1":420, "day2:":380, "day3":390}
myvar=pd.Series(ca, index = ["day1", "day3"])
myvar
# Out:
# day1    420
# day3    390
# dtype: int64

# %%
data = { "cal" : [420, 380, 390],
        "dur" : [50, 40, 45]}

df = pd.DataFrame(data)
df
# Out:
#    cal  dur
# 0  420   50
# 1  380   40
# 2  390   45

# %%
df = pd.read_csv('USA_housing.csv')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df = pd.read_csv('USA_housing.csv')
df.head()

#To show first five contant of csv file
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df = pd.read_csv('USA_housing.csv')
df.tail()

#To show last five contant of csv file
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
df.to_string()

#To show all contant of csv file
# Out:
# '      Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  Avg. Area Number of Bedrooms  Area Population         Price                                                                Address\n0         79545.458574             5.682861                   7.009188                          4.09     23086.800503  1.059034e+06                   208 Michael Ferry Apt. 674\\nLaurabury, NE 37010-5101\n1         79248.642455             6.002900                   6.730821                          3.09     40173.072174  1.505891e+06                   188 Johnson Views Suite 079\\nLake Kathleen, CA 48958\n2         61287.067179             5.865890                   8.512727                          5.13     36882.159400  1.058988e+06                    9127 Elizabeth Stravenue\\nDanieltown, WI 06482-3489\n3         63345.240046             7.188236                   5.586729                          3.26     34310.242831  1.260617e+06                                              U
# ...

# %%
df = pd.read_csv('USA_housing.csv', sep=";") #sep is indicate to seperation

# %%
import pandas as pd
data={
        "Name": "Shiv Patel",
        "Gender": "Male",
        "Country": "Indian",
        "Age": "23"
    }

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 9>()
#       1 import pandas as pd
#       2 data={
#       3         "Name": "Shiv Patel",
#       4         "Gender": "Male",
#       5         "Country": "Indian",
#       6         "Age": "23"
#       7     }
# ----> 9 df = pd.DataFrame(data)
#      10 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
df = pd.read_csv('C:/Users/Shiv/OneDrive/Desktop/123456.csv')
df

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Shiv/OneDrive/Desktop/123456.csv')
tf=df.groupby('color').sum("v2")
tf

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'First Name': ['Shiv', 'Aadi', 'Satish', 'Rana'],
                   'Last Name': ['Patel', 'Patel', 'Panchal', 'Aniket'],
                   'Type Name': ['Full Time Emp.', 'Intern', 'Full Time Emp.', 'Part-Time Emp.'],
                   'YoE': [2, 3, 4, 6],
                   'Department': ['Administration', 'Technical', 'Management', 'Swepper Staff'],
                   'Salary': [20000, 40000, 10000, 1000]})
df
# Out:
#   First Name Last Name       Type Name  YoE      Department  Salary
# 0       Shiv     Patel  Full Time Emp.    2  Administration   20000
# 1       Aadi     Patel          Intern    3       Technical   40000
# 2     Satish   Panchal  Full Time Emp.    4      Management   10000
# 3       Rana    Aniket  Part-Time Emp.    6   Swepper Staff    1000

# %%
df.pivot(index="Department", columns="YoE", values="Salary")
# Out:
# YoE                   2        3        4       6
# Department
# Administration  20000.0      NaN      NaN     NaN
# Management          NaN      NaN  10000.0     NaN
# Swepper Staff       NaN      NaN      NaN  1000.0
# Technical           NaN  40000.0      NaN     NaN

# %%
df.pivot(index="First Name", columns="Type Name", values="YoE")
# Out:
# Type Name   Full Time Emp.  Intern  Part-Time Emp.
# First Name
# Aadi                   NaN     3.0             NaN
# Rana                   NaN     NaN             6.0
# Satish                 4.0     NaN             NaN
# Shiv                   2.0     NaN             NaN

# %%
output = pd.pivot_table(data=df,
                       index=['Type Name'],
                       columns=['Department'],
                       # value='Salary',
                       aggfunc='mean') #aggfunc is the aggregate function for mean
output
# Out:
#                        Salary                                     \
# Department     Administration Management Swepper Staff Technical
# Type Name
# Full Time Emp.        20000.0    10000.0           NaN       NaN
# Intern                    NaN        NaN           NaN   40000.0
# Part-Time Emp.            NaN        NaN        1000.0       NaN
#
#                           YoE
# Department     Administration Management Swepper Staff Technical
# Type Name
# Full Time Emp.            2.0        4.0           NaN       NaN
# Intern                    NaN        NaN           NaN       3.0
# Part-Time Emp.            NaN        NaN           6.0       NaN

# %%
output = pd.pivot_table(data=df,
                       index=['Type Name'],
                       columns=['Department'],
                       values='Salary',
                       aggfunc='mean') #aggfunc is the aggregate function for mean
output
# Out:
# Department      Administration  Management  Swepper Staff  Technical
# Type Name
# Full Time Emp.         20000.0     10000.0            NaN        NaN
# Intern                     NaN         NaN            NaN    40000.0
# Part-Time Emp.             NaN         NaN         1000.0        NaN

# %%
# Calculate row and column totals (margins)

output = pd.pivot_table(data=df, index=['Type Name'],
                       #columns=['Department'],
                       values='Salary',
                       aggfunc=['mean', 'sum', 'count', 'max', 'min'],
                       margins=True,
                       margins_name='Total'
                       ) #aggfunc is the aggregate function for mean
output
# Out:
#                  mean    sum  count    max    min
#                Salary Salary Salary Salary Salary
# Type Name
# Full Time Emp.  15000  30000      2  20000  10000
# Intern          40000  40000      1  40000  40000
# Part-Time Emp.   1000   1000      1   1000   1000
# Total           17750  71000      4  40000   1000

# %%
output = pd.pivot_table(data=df, index=['Type Name'],
                       #columns=['Department'],
                       values=['YoE', 'Salary'],
                       aggfunc=['mean', 'sum', 'count', 'max', 'min'],
                       margins=True,
                       margins_name='Total'
                       ) #aggfunc is the aggregate function for mean
output
# Out:
#                  mean          sum      count        max        min
#                Salary   YoE Salary YoE Salary YoE Salary YoE Salary YoE
# Type Name
# Full Time Emp.  15000  3.00  30000   6      2   2  20000   4  10000   2
# Intern          40000  3.00  40000   3      1   1  40000   3  40000   3
# Part-Time Emp.   1000  6.00   1000   6      1   1   1000   6   1000   6
# Total           17750  3.75  71000  15      4   4  40000   6   1000   2

# %%
shiv = pd.pivot_table(data=df, index=['Type Name'],
                       columns=['Department'],
                       values=['YoE', 'Salary'],
                       aggfunc={'Salary': np.sum, 'YoE': np.mean})
shiv
# Out:
#                        Salary                                     \
# Department     Administration Management Swepper Staff Technical
# Type Name
# Full Time Emp.        20000.0    10000.0           NaN       NaN
# Intern                    NaN        NaN           NaN   40000.0
# Part-Time Emp.            NaN        NaN        1000.0       NaN
#
#                           YoE
# Department     Administration Management Swepper Staff Technical
# Type Name
# Full Time Emp.            2.0        4.0           NaN       NaN
# Intern                    NaN        NaN           NaN       3.0
# Part-Time Emp.            NaN        NaN           6.0       NaN

# %%
shiv = pd.pivot_table(data=df, index=['Type Name'],
                       columns=['Department'],
                       values=['YoE', 'Salary'],
                       aggfunc={'Salary': np.sum, 'YoE': np.mean},
                       fill_value='NA')
shiv
# Out:
#                        Salary                                     \
# Department     Administration Management Swepper Staff Technical
# Type Name
# Full Time Emp.        20000.0    10000.0            NA        NA
# Intern                     NA         NA            NA   40000.0
# Part-Time Emp.             NA         NA        1000.0        NA
#
#                           YoE
# Department     Administration Management Swepper Staff Technical
# Type Name
# Full Time Emp.            2.0        4.0            NA        NA
# Intern                     NA         NA            NA       3.0
# Part-Time Emp.             NA         NA           6.0        NA

# %%
output = pd.pivot_table(data=df, index=['Type Name', 'First Name', 'Last Name'],
                       #columns=['Department'],
                       values=['Salary'],
                       aggfunc=['mean', 'sum', 'count'],
                       margins=True,
                       margins_name='Grand Total'
                       ) #aggfunc is the aggregate function for mean
output
# Out:
#                                       mean    sum  count
#                                     Salary Salary Salary
# Type Name      First Name Last Name
# Full Time Emp. Satish     Panchal    10000  10000      1
#                Shiv       Patel      20000  20000      1
# Intern         Aadi       Patel      40000  40000      1
# Part-Time Emp. Rana       Aniket      1000   1000      1
# Grand Total                          17750  71000      4

# %%
import pandas as pd

data = {'Unemp_rate': [6.1,5.2,5.7,3.8,5.6,4.6,6.6],
        'stock_index_price': [1500,2000,1520,1560,1800,1750,1680]}

df = pd.DataFrame(data,columns=['Unemp_rate', 'stock_index_price'])
print(df)
# Out:
#    Unemp_rate  stock_index_price
# 0         6.1               1500
# 1         5.2               2000
# 2         5.7               1520
# 3         3.8               1560
# 4         5.6               1800
# 5         4.6               1750
# 6         6.6               1680

# %%
import matplotlib.pyplot as plt

df.plot(x = 'Unemp_rate', y = 'stock_index_price', kind = 'scatter')
plt.show();

# %%
df.plot(x = 'Unemp_rate', y = 'stock_index_price', kind = 'line', marker ='+', c = 'r')
plt.show();

# %%
data = {'country': ['USA', 'Canada', 'Germany', 'UK', 'India'],
       'GDP_Per_Capita': [45000, 42000, 52000, 49000, 60000]}

df = pd.DataFrame(data,columns=['country', 'GDP_Per_Capita'])
print(df);
# Out:
#    country  GDP_Per_Capita
# 0      USA           45000
# 1   Canada           42000
# 2  Germany           52000
# 3       UK           49000
# 4    India           60000

# %%
data = {'country': ['USA', 'Canada', 'Germany', 'UK', 'India'],
       'GDP_Per_Capita': [45000, 42000, 52000, 49000, 60000]}

df = pd.DataFrame(data,columns=['country', 'GDP_Per_Capita'])
print(df);
# plotting the points
plt.bar()

# naming the x axis
plt.xlabel('country')

# naming the y axis
plt.ylabel('GDP_Per_Capita')

# Giving the title Name
plt.suptitle("TITLE")
# Out:
#    country  GDP_Per_Capita
# 0      USA           45000
# 1   Canada           42000
# 2  Germany           52000
# 3       UK           49000
# 4    India           60000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 7>()
#       5 print(df);
#       6 # plotting the points
# ----> 7 plt.bar()
#       9 # naming the x axis
#      10 plt.xlabel('country')
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %%
data = {'country': ['USA', 'Canada', 'Germany', 'UK', 'India'],
       'GDP_Per_Capita': [45000, 42000, 52000, 49000, 60000] }
df = pd.DataFrame(data,columns=['country', 'GDP_Per_Capita'])
print(df);
df.plot(x='country', y='GDP_Per_Capita', kind = 'bar')
# Out:
#    country  GDP_Per_Capita
# 0      USA           45000
# 1   Canada           42000
# 2  Germany           52000
# 3       UK           49000
# 4    India           60000
# <AxesSubplot:xlabel='country'>

# %%
data = {'tasks': [300,200,500]}
df = pd.DataFrame(data,columns=['tasks'], index=['tasks pending', 'tasks ongoing', 'tasks completed'])
print(df)
# Out:
#                  tasks
# tasks pending      300
# tasks ongoing      200
# tasks completed    500

# %%
df.plot.pie(y='tasks', figsize=(10,5), autopct='%1.1f%%', startangle=90)
plt.show();
